# %% [markdown]
# ##Instalação e umportação

# %%
# pip install matplotlib pandas

# %%
from matplotlib import pyplot as plt
import pandas as pd

# %matplotlib inline

# %% [markdown]
# ##Baixando bases do COVID-19

# %%
# !pip install wget
# !wget https://raw.githubusercontent.com/diogocortiz/Crash-Course-IA/master/RegressaoLinear/FuelConsumptionCo2.csv

# %% [markdown]
# ##Manipulando base de dados: head

# %%
#Carregando base de dados CSV em um dataframe
dataframe = df = pd.read_csv("FuelConsumptionCo2.csv")

# print(df.head())
df.head()
# Out:
#    MODELYEAR   MAKE  ... FUELCONSUMPTION_COMB_MPG CO2EMISSIONS
# 0       2014  ACURA  ...                       33          196
# 1       2014  ACURA  ...                       29          221
# 2       2014  ACURA  ...                       48          136
# 3       2014  ACURA  ...                       25          255
# 4       2014  ACURA  ...                       27          244
#
# [5 rows x 13 columns]

# %% [markdown]
# ##Exibir uma descrição da base de dados

# %%
df.describe()
# Out:
#        MODELYEAR   ENGINESIZE  ...  FUELCONSUMPTION_COMB_MPG  CO2EMISSIONS
# count     1067.0  1067.000000  ...               1067.000000   1067.000000
# mean      2014.0     3.346298  ...                 26.441425    256.228679
# std          0.0     1.415895  ...                  7.468702     63.372304
# min       2014.0     1.000000  ...                 11.000000    108.000000
# 25%       2014.0     2.000000  ...                 21.000000    207.000000
# 50%       2014.0     3.400000  ...                 26.000000    251.000000
# 75%       2014.0     4.300000  ...                 31.000000    294.000000
# max       2014.0     8.400000  ...                 60.000000    488.000000
#
# [8 rows x 8 columns]

# %% [markdown]
# ##Exibindo informações

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 1067 entries, 0 to 1066
# Data columns (total 13 columns):
#  #   Column                    Non-Null Count  Dtype
# ---  ------                    --------------  -----
#  0   MODELYEAR                 1067 non-null   int64
#  1   MAKE                      1067 non-null   object
#  2   MODEL                     1067 non-null   object
#  3   VEHICLECLASS              1067 non-null   object
#  4   ENGINESIZE                1067 non-null   float64
#  5   CYLINDERS                 1067 non-null   int64
#  6   TRANSMISSION              1067 non-null   object
#  7   FUELTYPE                  1067 non-null   object
#  8   FUELCONSUMPTION_CITY      1067 non-null   float64
#  9   FUELCONSUMPTION_HWY       1067 non-null   float64
#  10  FUELCONSUMPTION_COMB      1067 non-null   float64
#  11  FUELCONSUMPTION_COMB_MPG  1067 non-null   int64
#  12  CO2EMISSIONS              1067 non-null   int64
# dtypes: float64(4), int64(4), object(5)
# ...

# %% [markdown]
# ##Selecionando atributos da base para a análise

# %%
veiculos_4WD = df[df['MODEL'].str.contains('4WD') == True]

print(veiculos_4WD)

# %%
df['CO2EMISSIONS'].value_counts(normalize=True)*100

# %% [markdown]
# ##Matplotlib

# %%
ano = [1999, 2000, 2001, 1950, 1966, 2010]
custo = [3000, 5000, 5555, 1593, 10000, 20000]

plt.bar(ano, custo, color='red')

plt.title("Primeiro plot")
plt.xlabel("Ano")
plt.ylabel("Custo")

plt.show()

# %%
# pip install seaborn

import seaborn as sns

sns.set()

df['MODEL'].value_counts(normalize=True).plot(kind='line', title="Exemplo")
